# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
# %config InlineBackend.figure_format='retina'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np

# %%
from descent.figure2d import Quadratic2D
from descent.figure3d import Quadratic3D, Cubic3D

# %% [markdown]
# # Quadratic 2D

# %%
quadratic_2d = Quadratic2D(3)
quadratic_2d.figure()

# %%
descent = {
    "descent": np.array([-5, -5, -3, -2, -1])
}
quadratic_2d.figure(descent=descent)

# %%
quadratic_3d = Quadratic3D()
quadratic_3d.figure()

# %%
descent = {
    "descent": np.array([[-4, 4], [-2, 2], [0, 0], [2, 2], [4, 4]])
}
quadratic_3d.figure(descent=descent)

# %%
cubic_3d = Cubic3D(np.array([10, 10]))
x = np.linspace(-10, 5, 100)
X = np.stack((x, x), axis=-1)
cube = cubic_3d.figure(X)
